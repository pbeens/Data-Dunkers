# %% [markdown]
# # Filtering Our Data
#
# (Open this notebook in [Callysto](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https://github.com/pbeens/Data-Dunkers&branch=main&subPath=Demos/filtering-data.ipynb&depth=1) | [Colab](https://githubtocolab.com/pbeens/Data-Dunkers/blob/main/Demos/filtering-data.ipynb))

# %% [markdown]
# ## Lesson Objectives

# %% [markdown]
# By the end of this lesson, students will be able to:
# - Learn how to filter data to focus on what’s important. *(Example: Filter Pascal Siakam's basketball statistics to only include seasons up to 2022-23.)*
# - Understand the process of refining data for better analysis. *(Example: Remove irrelevant seasons and columns from Pascal Siakam's data to focus on his key performance metrics.)*
# - Apply simple techniques to clean and prepare data for use. *(Example: Clean a dataset by filtering out entries with incomplete information and focusing on relevant columns.)*

# %% [markdown]
# ## Let’s Get Our Data

# %%
import pandas as pd

# URL of the CSV file containing data for Pascal Siakam
url = 'https://raw.githubusercontent.com/pbeens/Data-Dunkers/main/Data/Pascal_Siakam.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(url)

# Display the DataFrame
display(df)

# %% [markdown]
# ## Only Include Seasons with the Raptors

# %% [markdown]
# There are a few things you will notice from the data above. The first is that it includes data from the year Pascal Siakam was traded to the Indiana Pacers, as well as a line that has totals and averages for his career. To eliminate these, we can simply make sure we only include anything up to and including the 2022-23 season.

# %%
# Filter the DataFrame to exclude seasons after 2022-23
filter = df['SEASON_ID'] <= '2022-23'
df = df[filter]

display(df)

# %% [markdown]
# ## How to Reduce the Number of Columns
#
# Let's reduce the number of columns to make it easier to work with. To do this we set up a filter, first by specifying the columns we want to keep, then using that filter to filter the DataFrame.

# %%
# Filter the DataFrame to only include specific columns
columns_to_keep = [
    'SEASON_ID','PLAYER_AGE', 'GP', 'GS', 'MIN', 'AST', 'STL', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 
    'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'PTS', 'FG2M', 'FG2A', 'FG2_PCT' 
]

df = df[columns_to_keep]
display(df)

# %% [markdown]
# ## Filtering By Free Throw Percentage > 75%
#
# We can filter the data to only display rows where Pascal Siakam's free throw percentage was greater than 75%.

# %%
filter = df['FT_PCT'] > 0.75 # free throw % above 75%
display(df[filter])

# %% [markdown]
# ## ...and When He Started Every Game
#
# What if we only want to display the seasons where he started every game. Logically, that would be where the number of games played (GS) equals the number of games started (GS). We can filter using `==` which means "is equal to".

# %%
filter = df['GS'] == df['GP'] # games started equals games
display(df[filter])

# %% [markdown]
# It is even possible to include multiple conditions. "`&`" means "and".

# %%
filter_1 = df['FT_PCT'] > 0.75 # free throw % above 75%
filter_2 = df['GS'] == df['GP'] # games started equals games
display(df[filter_1 & filter_2])

# %% [markdown]
# These are the symbols we use for comparison operations in Python:
#
# |Symbol|Meaning|
# |-|-|
# |>|greater than|
# |<|less than|
# |==|is equal to|
# |!=|not equal to|
# |>=|greater than or equal to|
# |<=|less than or equal to|
# |&|and|
# |\||or|

# %% [markdown]
# ## Exercise

# %% [markdown]
# In the cell below, update the program to display only rows where Assists ('AST') were greater than 200 or Steals ('STL') were greater than 50.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/pbeens/Data-Dunkers/main/Data/Pascal_Siakam.csv'

df = pd.read_csv(url)

# Filter the DataFrame to exclude seasons after 2022-23
df = df[df['SEASON_ID'] <= '2022-23']

# filter_1 = 
# filter_2 = 
display(df)

# %% [markdown]
# ---
# *Report issues or give us feedback about this notebook [here](https://docs.google.com/forms/d/e/1FAIpQLSdMRX2hPqZyD8-argFJXxB3ABQdLk3aUH1CAfmMEtcFAlWzCw/viewform?usp=pp_url&entry.1771525592=Module%20Resources%20%28the%20Jupyter%20notebooks%2C%20PPTS%20or%20additional%20resources%29&entry.1364186163=Filtering%20Our%20Data).*
#
#
# ---
# Back to [Lessons](https://github.com/pbeens/Data-Dunkers/blob/main/Lessons.ipynb)
#
# ---
# This notebook has been adapted from...
#
# https://github.com/callysto/basketball-and-data-science/blob/main/content/01-introduction.ipynb, with permission.
